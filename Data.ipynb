# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
sp500url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
data_table = pd.read_html(sp500url)

# %%
data_table
# Out:
# [    Symbol            Security             GICS Sector  \
#  0      MMM                  3M             Industrials
#  1      AOS         A. O. Smith             Industrials
#  2      ABT              Abbott             Health Care
#  3     ABBV              AbbVie             Health Care
#  4      ACN           Accenture  Information Technology
#  ..     ...                 ...                     ...
#  498    XYL          Xylem Inc.             Industrials
#  499    YUM         Yum! Brands  Consumer Discretionary
#  500   ZBRA  Zebra Technologies  Information Technology
#  501    ZBH       Zimmer Biomet             Health Care
#  502    ZTS              Zoetis             Health Care
#
#                                  GICS Sub-Industry    Headquarters Location  \
#  0                        Industrial Conglomerates    Saint Paul, Minnesota
#  1                               Building Products     Milwaukee, Wisconsin
# ...

# %%
data_table[0]
# Out:
#     Symbol            Security             GICS Sector  \
# 0      MMM                  3M             Industrials
# 1      AOS         A. O. Smith             Industrials
# 2      ABT              Abbott             Health Care
# 3     ABBV              AbbVie             Health Care
# 4      ACN           Accenture  Information Technology
# ..     ...                 ...                     ...
# 498    XYL          Xylem Inc.             Industrials
# 499    YUM         Yum! Brands  Consumer Discretionary
# 500   ZBRA  Zebra Technologies  Information Technology
# 501    ZBH       Zimmer Biomet             Health Care
# 502    ZTS              Zoetis             Health Care
#
#                                 GICS Sub-Industry    Headquarters Location  \
# 0                        Industrial Conglomerates    Saint Paul, Minnesota
# 1                               Building Products     Milwaukee, Wisconsin
# 2                           Health Care Equipment  North Chicago, Illinois
# ...

# %%
ticker = data_table[0]['Symbol'].tolist()

# %%
ticker
# Out:
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE',
#  'AAL',
#  'AEP',
#  'AXP',
#  'AIG',
#  'AMT',
#  'AWK',
#  'AMP',
#  'AME',
#  'AMGN',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AON',
#  'APA',
#  'AAPL',
#  'AMAT',
#  'APTV',
#  'ACGL',
#  'ADM',
#  'ANET',
#  'AJG',
#  'AIZ',
#  'T',
#  'ATO',
#  'ADSK',
#  'ADP',
#  'AZO',
#  'AVB',
#  'AVY',
#  'AXON',
#  'BKR',
#  'BALL',
#  'BAC',
#  'BK',
#  'BBWI',
#  'BAX',
#  'BDX',
#  'BRK.B',
#  'BBY',
#  'BIO',
#  'TECH',
#  'BIIB',
#  'BLK',
#  'BX',
#  'BA',
#  'BKNG',
#  'BWA',
#  'BXP',
#  'BSX',
#  'BMY',
#  'AVGO',
#  'BR',
#  'BRO',
#  'BF.B',
#  'BLDR',
#  'BG',
#  'CDNS',
#  'CZR',
#  'CPT',
#  'CPB',
#  'COF',
#  'CAH',
#  'KMX',
#  'CCL',
#  'CARR',
#  'CTLT',
#  'CAT',
#  'CBOE',
#  'CBRE',
#  'CDW',
#  'CE',
#  'COR',
# ...

# %%
snp_prices = yf.download(ticker, start = '2021-01-01', end = '2021-01-31')
# Out:
# [*********************100%%**********************]  503 of 503 completed
#
# 6 Failed downloads:
# ['KVUE', 'CEG', 'SOLV', 'GEV', 'VLTO', 'GEHC']: Exception("%ticker%: Data doesn't exist for startDate = 1609477200, endDate = 1612069200")

# %% [markdown]
# ## Here we got 11 failed downloads. We will try and see what is the problem with the data and try to overcome this challenge

# %% [raw]
# Brown-Forman Corporation Class B
# NYSE: BF.B
#
# Berkshire Hathaway Inc. (BRK-B)
#
# 1. Instead of BF.B we need to use BF-B
# 2. Instead of BRK.B we need to use BRK-B
#
# and for the rest of others some of the stocks were not publicaly listed during this time. Hence we will change the timeline.

# %%
replacements = {'BF.B': 'BF-B', 'BRK.B': 'BRK-B'}
ticker = [replacements.get(x, x) for x in ticker]

# %%
len(snp_prices)
# Out:
# 19

# %%
snp_prices.columns
# Out:
# MultiIndex([('Adj Close',    'A'),
#             ('Adj Close',  'AAL'),
#             ('Adj Close', 'AAPL'),
#             ('Adj Close', 'ABBV'),
#             ('Adj Close', 'ABNB'),
#             ('Adj Close',  'ABT'),
#             ('Adj Close', 'ACGL'),
#             ('Adj Close',  'ACN'),
#             ('Adj Close', 'ADBE'),
#             ('Adj Close',  'ADI'),
#             ...
#             (   'Volume',  'WTW'),
#             (   'Volume',   'WY'),
#             (   'Volume', 'WYNN'),
#             (   'Volume',  'XEL'),
#             (   'Volume',  'XOM'),
#             (   'Volume',  'XYL'),
#             (   'Volume',  'YUM'),
#             (   'Volume',  'ZBH'),
#             (   'Volume', 'ZBRA'),
#             (   'Volume',  'ZTS')],
#            names=['Price', 'Ticker'], length=3018)

# %%
for i in range(len(snp_prices)):
    print(snp_prices.columns[i])
# Out:
# ('Adj Close', 'A')
# ('Adj Close', 'AAL')
# ('Adj Close', 'AAPL')
# ('Adj Close', 'ABBV')
# ('Adj Close', 'ABNB')
# ('Adj Close', 'ABT')
# ('Adj Close', 'ACGL')
# ('Adj Close', 'ACN')
# ('Adj Close', 'ADBE')
# ('Adj Close', 'ADI')
# ('Adj Close', 'ADM')
# ('Adj Close', 'ADP')
# ('Adj Close', 'ADSK')
# ('Adj Close', 'AEE')
# ('Adj Close', 'AEP')
# ('Adj Close', 'AES')
# ('Adj Close', 'AFL')
# ('Adj Close', 'AIG')
# ('Adj Close', 'AIZ')

# %%
snp_prices.isnull().any().sum()
# Out:
# 36

# %%
snp_prices.head(100)
# Out:
# Price        Adj Close                                                 \
# Ticker               A        AAL        AAPL        ABBV        ABNB
# Date
# 2021-01-04  116.195976  15.130000  127.002106   99.552361  139.149994
# 2021-01-05  117.146011  15.430000  128.572327  100.581787  148.300003
# 2021-01-06  120.358429  15.520000  124.244370   99.712906  142.770004
# 2021-01-07  123.561066  15.380000  128.483978  100.780106  151.270004
# 2021-01-08  124.442543  15.130000  129.592972  101.308983  149.770004
# 2021-01-11  125.510071  15.000000  126.580086  102.961754  148.130005
# 2021-01-12  124.354378  15.380000  126.403473  103.679520  160.800003
# 2021-01-13  124.364189  15.530000  128.454575  106.201141  169.990005
# 2021-01-14  123.433754  16.440001  126.511406  106.659760  180.500000
# 2021-01-15  123.610046  15.760000  124.774338  105.599190  169.270004
# 2021-01-19  124.726555  15.970000  125.451508  107.185280  173.690002
# ...

# %%
snp_prices.describe()
# Out:
# Price    Adj Close                                                             \
# Ticker           A        AAL        AAPL        ABBV        ABNB         ABT
# count    19.000000  19.000000   19.000000   19.000000   19.000000   19.000000
# mean    122.034239  15.856842  130.561459  103.120805  168.434738  106.399021
# std       3.204786   0.769199    5.342104    3.276184   18.133159    3.588653
# min     116.195976  15.000000  124.244370   97.917168  139.149994  102.342491
# 25%     119.707130  15.405000  126.545746  100.147346  150.520004  104.055401
# 50%     123.561066  15.530000  128.572327  103.679520  169.990005  105.454910
# 75%     124.373981  16.070000  134.431229  106.062595  181.184998  107.267544
# max     125.510071  18.100000  140.496277  107.605690  201.250000  116.680122
#
# Price                                                  ...        Volume  \
# Ticker       ACGL         ACN        ADBE         ADI  ...           WTW
# ...

# %%
snp_prices.to_excel(excel_writer='demo.xlsx')

# %%
# !pip install xlrd
# !pip install xlwt
# !pip install openpyxl
# Out:
# ...
#   Obtaining dependency information for xlrd from https://files.pythonhosted.org/packages/a6/0c/c2a72d51fe56e08a08acc85d13013558a2d793028ae7385448a6ccdfae64/xlrd-2.0.1-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 2.2 MB/s eta 0:00:00a 0:00:01
# ...
#   Obtaining dependency information for xlwt from https://files.pythonhosted.org/packages/44/48/def306413b25c3d01753603b1a222a011b8621aed27cd7f89cbc27e6b0f4/xlwt-1.3.0-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0/100.0 kB 2.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
len(snp_prices.index)
# Out:
# 20

# %%
type(snp_prices)
# Out:
# pandas.core.frame.DataFrame

# %%
snp_prices
# Out:
# Price        Adj Close                                                 \
# Ticker               A        AAL        AAPL        ABBV        ABNB
# Date
# 2021-01-04  116.195976  15.130000  127.002106   99.552361  139.149994
# 2021-01-05  117.146011  15.430000  128.572327  100.581787  148.300003
# 2021-01-06  120.358429  15.520000  124.244370   99.712906  142.770004
# 2021-01-07  123.561066  15.380000  128.483978  100.780106  151.270004
# 2021-01-08  124.442543  15.130000  129.592972  101.308983  149.770004
# 2021-01-11  125.510071  15.000000  126.580086  102.961754  148.130005
# 2021-01-12  124.354378  15.380000  126.403473  103.679520  160.800003
# 2021-01-13  124.364189  15.530000  128.454575  106.201141  169.990005
# 2021-01-14  123.433754  16.440001  126.511406  106.659760  180.500000
# 2021-01-15  123.610046  15.760000  124.774338  105.599190  169.270004
# 2021-01-19  124.726555  15.970000  125.451508  107.185280  173.690002
# ...
